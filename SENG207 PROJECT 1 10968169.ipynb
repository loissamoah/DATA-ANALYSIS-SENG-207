# %% [markdown]
# # Importing Data set values

# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %% [markdown]
# # Data set values

# %%
df
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# # Getting  rid of all null values and duplicates.

# %% [markdown]
# #### Before beginning the analysis, I pre-processed the data to get rid of null values and duplicates. I checked for
#
# #### missing values using the `isnull()` method and removed them using the `dropna()` method. I also checked for
#
# #### duplicates using the `duplicated()` method and removed them using the `drop_duplicates()` method.

# %%
# check for missing values
print(df.isnull().sum())
# Out:
# ID                      0
# fixed acidity           1
# volatile acidity        0
# citric acid             1
# residual sugar          0
# chlorides               3
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 1
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %% [markdown]
# #### In the event of null values,The `dropna()` function drops all rows with missing
#
# ####  values (i.e. NaN values) from the data set. Setting the `inplace` parameter to
#
# #### `True` modifies the data set directly rather than creating a copy.

# %%
# Dropping all rows with null values
df.dropna(inplace=True)

# Dropping all duplicates
df.drop_duplicates(inplace=True)

# Reset the index after dropping rows
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# # Data set of values after getting rid of all null values and duplicates.

# %%
df
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        4           11.2             0.280         0.56             1.9
# 3        5            7.4             0.700         0.00             1.9
# 4        6            7.4             0.660         0.00             1.8
# ...    ...            ...               ...          ...             ...
# 1586  1597            5.9             0.550         0.10             2.2
# 1587  1598            6.3             0.510         0.13             2.3
# 1588  1599            5.9             0.645         0.12             2.0
# 1589  1600            6.0             0.310         0.47             3.6
# 1590  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# # Statistical inferences of the entire dataset

# %%
# Showing statistical inferences of the entire dataset
dataset = df.describe()
df.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1591.000000    1591.000000       1591.000000  1591.000000
# mean    801.060968       8.320616          0.527681     0.271477
# std     460.740942       1.740134          0.179045     0.194807
# min       1.000000       4.600000          0.120000     0.000000
# 25%     402.500000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1199.500000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1591.000000  1591.000000          1591.000000           1591.000000
# mean         2.540761     0.087500            15.861722             46.498429
# std          1.413076     0.047175            10.429385             32.998659
# ...

# %%
import matplotlib.pyplot as plt


# plotting a pie chart of the summary statistics of entire data set
plt.pie(x = dataset.ID , autopct='%1.1f%%')
plt.title("A Pie Chart illustrating the entire Dataset Summary Statistics")

plt.show()

# %% [markdown]
#  # Statistical Inferences of Fixed Acidity

# %%
print("Mean:", df["fixed acidity"].mean())
print("Median:",df["fixed acidity"].median())
print("Mode:", df["fixed acidity"].mode())
print("Standard Deviation:",df["fixed acidity"].std())
print("Variance:",df["fixed acidity"].var())
print("Minimum Value:",df["fixed acidity"].min())
print("Maximum Value:",df["fixed acidity"].max())


 
# plotting a histogram of  residual sugar

plt.hist(df["fixed acidity"], bins=10)
plt.title("Histogram of  fixed acidity  ")
plt.xlabel("fixed acidity")
plt.ylabel("Frequency")
plt.show()
# Out:
# Mean: 8.319875000000001
# Median: 7.9
# Mode: 0    7.2
# Name: fixed acidity, dtype: float64
# Standard Deviation: 1.7400387405562694
# Variance: 3.0277348186366484
# Minimum Value: 4.6
# Maximum Value: 15.9

# %% [markdown]
# # Statistical Inferences of residual sugar

# %%
import pandas as pd

# load the CSV file into a Pandas dataframe
df = pd.read_csv("data.csv")
df

print("Mean:", df["residual sugar"].mean())
print("Median:",df["residual sugar"].median())
print("Mode:", df["residual sugar"].mode())
print("Standard Deviation:",df["residual sugar"].std())
print("Variance:",df["residual sugar"].var())
print("Minimum Value:",df["residual sugar"].min())
print("Maximum Value:",df["residual sugar"].max())

# plotting a histogram of  residual sugar

plt.hist(df["residual sugar"], bins=10)
plt.title("Histogram of residual sugar")
plt.xlabel("residual sugar")
plt.ylabel("Frequency")
plt.show()
# Out:
# Mean: 2.5384447220487196
# Median: 2.2
# Mode: 0    2.0
# Name: residual sugar, dtype: float64
# Standard Deviation: 1.4091378630562335
# Variance: 1.9856695170986884
# Minimum Value: 0.9
# Maximum Value: 15.5

# %% [markdown]
# # Statistical Inferences of Volatile Acidity

# %%
print("Mean:", df["volatile acidity"].mean())
print("Median:",df["volatile acidity"].median())
print("Mode:", df["volatile acidity"].mode())
print("Standard Deviation:",df["volatile acidity"].std())
print("Variance:",df["volatile acidity"].var())
print("Minimum Value:",df["volatile acidity"].min())
print("Maximum Value:",df["volatile acidity"].max())

# plotting a histogram of a volatile acidity

plt.hist(df["volatile acidity"], bins=10)
plt.title("Histogram of volatile acidity")
plt.xlabel("volatile acidity")
plt.ylabel("Frequency")
plt.show()
# Out:
# Mean: 0.5276807039597737
# Median: 0.52
# Mode: 0    0.6
# Name: volatile acidity, dtype: float64
# Standard Deviation: 0.1790451469674224
# Variance: 0.03205716465258589
# Minimum Value: 0.12
# Maximum Value: 1.58

# %% [markdown]
# # Statistical Inferences of Citric Acid

# %%
print("Mean:", df["citric acid"].mean())
print("Median:",df["citric acid"].median())
print("Mode:", df["citric acid"].mode())
print("Standard Deviation:",df["citric acid"].std())
print("Variance:",df["citric acid"].var())
print("Minimum Value:",df["citric acid"].min())
print("Maximum Value:",df["citric acid"].max())

# plotting a histogram of a citric acid

plt.hist(df["citric acid"], bins=10)
plt.title("Histogram of citric acid ")
plt.xlabel("citric acid")
plt.ylabel("Frequency")
plt.show()
# Out:
# Mean: 0.27147705845380266
# Median: 0.26
# Mode: 0    0.0
# Name: citric acid, dtype: float64
# Standard Deviation: 0.19480651409147987
# Variance: 0.037949577932473944
# Minimum Value: 0.0
# Maximum Value: 1.0

# %% [markdown]
# #  Statistical Inferences of chlorides

# %%
print("Mean:", df["chlorides"].mean())
print("Median:",df["chlorides"].median())
print("Mode:", df["chlorides"].mode())
print("Standard Deviation:",df["chlorides"].std())
print("Variance:",df["chlorides"].var())
print("Minimum Value:",df["chlorides"].min())
print("Maximum Value:",df["chlorides"].max())
 
    
# plotting a histogram of a chlorides

plt.hist(df["chlorides"], bins=10)
plt.title("Histogram of chlorides ")
plt.xlabel("chlorides")
plt.ylabel("Frequency")
plt.show()
# Out:
# Mean: 0.08749968573224387
# Median: 0.079
# Mode: 0    0.08
# Name: chlorides, dtype: float64
# Standard Deviation: 0.0471746637430755
# Variance: 0.0022254488992722427
# Minimum Value: 0.012
# Maximum Value: 0.611

# %% [markdown]
# # Statistical Inferences of total sulfur dioxide

# %%
print("Mean:", df["total sulfur dioxide"].mean())
print("Median:",df["total sulfur dioxide"].median())
print("Mode:", df["total sulfur dioxide"].mode())
print("Standard Deviation:",df["total sulfur dioxide"].std())
print("Variance:",df["total sulfur dioxide"].var())
print("Minimum Value:",df["total sulfur dioxide"].min())
print("Maximum Value:",df["total sulfur dioxide"].max())


# plotting a histogram of a  total sulfur oxide

plt.hist(df["total sulfur dioxide"], bins=10)
plt.title("Histogram of total sulfur dioxide ")
plt.xlabel("total sulfur dioxide")
plt.ylabel("Frequency")
plt.show()
# Out:
# Mean: 46.49842866121936
# Median: 38.0
# Mode: 0    28.0
# Name: total sulfur dioxide, dtype: float64
# Standard Deviation: 32.998658692691784
# Variance: 1088.911475516763
# Minimum Value: 6.0
# Maximum Value: 289.0

# %% [markdown]
# # Statistical Inferences of density

# %%
print("Mean:", df["density"].mean())
print("Median:",df["density"].median())
print("Mode:", df["density"].mode())
print("Standard Deviation:",df["density"].std())
print("Variance:",df["density"].var())
print("Minimum Value:",df["density"].min())
print("Maximum Value:",df["density"].max())

# plot a histogram of a variable
plt.hist(df["density"], bins=10)
plt.title("Histogram of density ")
plt.xlabel("density")
plt.ylabel("Frequency")
plt.show()
# Out:
# Mean: 0.9967465304839724
# Median: 0.99675
# Mode: 0    0.9972
# Name: density, dtype: float64
# Standard Deviation: 0.0018891416386783645
# Variance: 3.5688561309883766e-06
# Minimum Value: 0.99007
# Maximum Value: 1.00369

# %% [markdown]
# # Statistical Inferences of free sulfur dioxide

# %%
print("Mean:", df["free sulfur dioxide"].mean())
print("Median:",df["free sulfur dioxide"].median())
print("Mode:", df["free sulfur dioxide"].mode())
print("Standard Deviation:",df["free sulfur dioxide"].std())
print("Variance:",df["free sulfur dioxide"].var())
print("Minimum Value:",df["free sulfur dioxide"].min())
print("Maximum Value:",df["free sulfur dioxide"].max())

# plot a histogram of a  free sulfur dioxide
plt.hist(df["free sulfur dioxide"], bins=10)
plt.title("Histogram of free sulfur dioxide ")
plt.xlabel("free sulfur dioxide")
plt.ylabel("Frequency")
plt.show()
# Out:
# Mean: 15.886875
# Median: 14.0
# Mode: 0    6.0
# Name: free sulfur dioxide, dtype: float64
# Standard Deviation: 10.45848651560053
# Variance: 109.3799401969981
# Minimum Value: 1.0
# Maximum Value: 72.0

# %% [markdown]
# # Statistical Inferences of pH

# %%
print("Mean:", df["pH"].mean())
print("Median:",df["pH"].median())
print("Mode:", df["pH"].mode())
print("Standard Deviation:",df["pH"].std())
print("Variance:",df["pH"].var())
print("Minimum Value:",df["pH"].min())
print("Maximum Value:",df["pH"].max())

# plot a histogram of a pH
plt.hist(df["pH"], bins=10)
plt.title("Histogram of pH ")
plt.xlabel("pH")
plt.ylabel("Frequency")
plt.show()
# Out:
# Mean: 3.3113576367064743
# Median: 3.31
# Mode: 0    3.3
# Name: pH, dtype: float64
# Standard Deviation: 0.15454755939895115
# Variance: 0.023884948116172335
# Minimum Value: 2.74
# Maximum Value: 4.01

# %% [markdown]
# # Statistical Inferences of  sulphates

# %%
print("Mean:", df["sulphates"].mean())
print("Median:",df["sulphates"].median())
print("Mode:", df["sulphates"].mode())
print("Standard Deviation:",df["sulphates"].std())
print("Variance:",df["sulphates"].var())
print("Minimum Value:",df["sulphates"].min())
print("Maximum Value:",df["sulphates"].max())

# plot a histogram of sulphates
plt.hist(df["sulphates"], bins=10)
plt.title("Histogram of sulphates ")
plt.xlabel("sulphates")
plt.ylabel("Frequency")
plt.show()
# Out:
# Mean: 0.6586109365179132
# Median: 0.62
# Mode: 0    0.6
# Name: sulphates, dtype: float64
# Standard Deviation: 0.16978645516738008
# Variance: 0.02882744035830477
# Minimum Value: 0.33
# Maximum Value: 2.0

# %% [markdown]
# # Statistical Inferences of alcohol

# %%
print("Mean:", df["alcohol"].mean())
print("Median:",df["alcohol"].median())
print("Mode:", df["alcohol"].mode())
print("Standard Deviation:",df["alcohol"].std())
print("Variance:",df["alcohol"].var())
print("Minimum Value:",df["alcohol"].min())
print("Maximum Value:",df["alcohol"].max())

# plot a histogram of alcohol
plt.hist(df["alcohol"], bins=10)
plt.title("Histogram of alcohol ")
plt.xlabel("alcohol")
plt.ylabel("Frequency")
plt.show()
# Out:
# Mean: 10.42605279698303
# Median: 10.2
# Mode: 0    9.5
# Name: alcohol, dtype: float64
# Standard Deviation: 1.0667057613499136
# Variance: 1.1378611812970987
# Minimum Value: 8.4
# Maximum Value: 14.9

# %% [markdown]
# # Statistical Inferences of quality

# %%
print("Mean:", df["quality"].mean())
print("Median:",df["quality"].median())
print("Mode:", df["quality"].mode())
print("Standard Deviation:",df["quality"].std())
print("Variance:",df["quality"].var())
print("Minimum Value:",df["quality"].min())
print("Maximum Value:",df["quality"].max())

# plot a histogram of quality
plt.hist(df["quality"], bins=10)
plt.title("Histogram ofquality")
plt.xlabel("quality")
plt.ylabel("Frequency")
plt.show()
# Out:
# Mean: 5.637963544940289
# Median: 6.0
# Mode: 0    5.0
# Name: quality, dtype: float64
# Standard Deviation: 0.8077716074110152
# Variance: 0.6524949697393752
# Minimum Value: 3.0
# Maximum Value: 8.0

# %% [markdown]
# # Statistical Inferences of ID

# %%
print("Mean:", df["ID"].mean())
print("Median:",df["ID"].median())
print("Mode:", df["ID"].mode())
print("Standard Deviation:",df["ID"].std())
print("Variance:",df["ID"].var())
print("Minimum Value:",df["ID"].min())
print("Maximum Value:",df["ID"].max())

# plot a histogram of a variable
plt.hist(df["ID"], bins=10)
plt.title("Histogram of ID ")
plt.xlabel("ID")
plt.ylabel("Frequency")
plt.show()
# Out:
# Mean: 801.0609679446889
# Median: 801.0
# Mode: 0          1
# 1          2
# 2          4
# 3          5
# 4          6
#         ...
# 1586    1597
# 1587    1598
# 1588    1599
# 1589    1600
# 1590    1601
# Name: ID, Length: 1591, dtype: int64
# Standard Deviation: 460.74094215451186
# Variance: 212282.21577742725
# Minimum Value: 1
# Maximum Value: 1601

# %% [markdown]
# # Correlation between columns

# %%
# showing  the correlation between columns
correlation = df.corr()
print(correlation)
# Out:
#                             ID  fixed acidity  volatile acidity  citric acid  \
# ID                    1.000000      -0.268147         -0.009544    -0.153429
# fixed acidity        -0.268147       1.000000         -0.255570     0.671061
# volatile acidity     -0.009544      -0.255570          1.000000    -0.552917
# citric acid          -0.153429       0.671061         -0.552917     1.000000
# residual sugar       -0.031589       0.114601          0.001877     0.143518
# chlorides            -0.119363       0.093544          0.060826     0.204054
# free sulfur dioxide   0.091197      -0.153049         -0.010592    -0.061269
# total sulfur dioxide -0.113913      -0.113356          0.076249     0.036030
# density              -0.368825       0.667912          0.022771     0.364309
# pH                    0.135208      -0.682644          0.235306    -0.543019
# sulphates            -0.124243       0.182303         -0.261364     0.312895
# ...

# %% [markdown]
# # Heat map showing correlation between colums

# %%
import pandas as pd
import seaborn as sns

# load the dataset
df = pd.read_csv("data.csv")

# calculate the correlation matrix
corr_matrix = df.corr()

# plot a heatmap of the correlation matrix
sns.heatmap(corr_matrix, annot=True, cmap="YlGnBu")

# show the plot
plt.show()
